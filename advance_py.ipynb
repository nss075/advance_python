# %% [markdown]
# <a href="https://colab.research.google.com/github/nss075/advance_python/blob/main/advance_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as r
import string
no_of_lines = 1000
string_length = 5

with open('random_strings.txt','w') as file:
  for i in range(no_of_lines):
    random_string = ''.join(r.choices(string.ascii_letters + string.digits, k = string_length))
    file.write(random_string + '\n')

# %%
import random as r
import string as str

file_size = 5*1024*1024

with open('random_strings.txt','wb') as file:
  while file.tell() < file_size:
    random_string= ''.join(r.choices(str.ascii_letters + str.digits,k =3))
    file.write(random_string.encode() + b'\n')

# %%
import random as r
import string as str

file_size = 5*1024*1024

for i in range(1,11):
  with open('random_strings.txt','wb') as file:
    while file.tell() < file_size:
      for i in range(no_of_lines):
        random_string= ''.join(r.choices(str.ascii_letters + str.digits,k =3))
        file.write(random_string.encode() + b'\n')

# %%
import random as r
import string as str

file_size1 = 1*1024*1024
file_size2 = 2*1024*1024
file_size3 = 3*1024*1024
file_size4 = 4*1024*1024
file_size5 = 5*1024*1024

with open('random_strings1.txt','wb') as file:
  while file.tell() < file_size1:
    random_string= ''.join(r.choices(str.ascii_letters + str.digits,k =3))
    file.write(random_string.encode() + b'\n')

with open('random_strings2.txt','wb') as file:
  while file.tell() < file_size2:
    random_string= ''.join(r.choices(str.ascii_letters + str.digits,k =3))
    file.write(random_string.encode() + b'\n')


with open('random_strings3.txt','wb') as file:
  while file.tell() < file_size3:
    random_string= ''.join(r.choices(str.ascii_letters + str.digits,k =3))
    file.write(random_string.encode() + b'\n')

with open('random_strings4.txt','wb') as file:
  while file.tell() < file_size4:
    random_string= ''.join(r.choices(str.ascii_letters + str.digits,k =3))
    file.write(random_string.encode() + b'\n')

with open('random_strings5.txt','wb') as file:
  while file.tell() < file_size5:
    random_string= ''.join(r.choices(str.ascii_letters + str.digits,k =3))
    file.write(random_string.encode() + b'\n')

# %%
import random
import string

# Function to generate random strings
def generate_random_strings(num_lines):
    random_strings = []
    for _ in range(num_lines):
        random_string = ''.join(random.choices(string.ascii_letters + string.digits, k=10))
        random_strings.append(random_string)
    return random_strings

# Function to write random strings to a file
def write_random_strings_to_file(file_path, random_strings):
    with open(file_path, 'w') as file:
        file.writelines('\n'.join(random_strings))

# Function to convert file contents to uppercase
def convert_file_to_uppercase(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        uppercase_lines = [line.upper() for line in lines]
    with open(file_path, 'w') as file:
        file.writelines(uppercase_lines)

# File sizes in bytes
file_sizes = [1 * 1024*2, 2 * 1024*2, 3 * 1024*2, 4 * 1024*2, 5 * 1024*2]

# %%
import random as r
import string as str

file_size = 5*1024*1024
num_files = 10

for file_num in range(num_files):
  file_name = f'random_strings_{file_num}.txt'

  with open(file_name,'wb') as file:
    while file.tell()< file_size:
      random_string = ''.join(r.choices(str.ascii_letters + str.digits, k=10))
      file.write(random_string.encode() + b'\n')

# %%
import random
import string

# Function to generate random strings
def generate_random_strings(num_lines):
    random_strings = []
    for _ in range(num_lines):
        random_string = ''.join(random.choices(string.ascii_letters + string.digits, k=10))
        random_strings.append(random_string)
    return random_strings

# Function to write random strings to a file
def write_random_strings_to_file(file_path, random_strings):
    with open(file_path, 'w') as file:
        file.writelines('\n'.join(random_strings))

# Function to convert file contents to uppercase
def convert_file_to_uppercase(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        uppercase_lines = [line.upper() for line in lines]
    with open(file_path, 'w') as file:
        file.writelines(uppercase_lines)

# File sizes in bytes
file_sizes = [1 * 1024**2, 2 * 1024**2, 3 * 1024**2, 4 * 1024**2, 5 * 1024**2]

# Generate and convert files
for i, size in enumerate(file_sizes):
    # Generate random strings
      num_lines = size // 50  # Approximate number of lines based on average line size
      random_strings = generate_random_strings(num_lines)

    # Create file
      file_path = f'file_{i}.txt'
      write_random_strings_to_file(file_path, random_strings)

    # Convert file to uppercase
      convert_file_to_uppercase(file_path)

# %%
import random
import string

# Function to generate random strings
def generate_random_strings(num_lines):
    random_strings = []
    for _ in range(num_lines):
        random_string = ''.join(random.choices(string.ascii_letters + string.digits, k=10))
        random_strings.append(random_string)
    return random_strings

# Function to write random strings to a file
def write_random_strings_to_file(file_path, random_strings):
    with open(file_path, 'w') as file:
        file.writelines('\n'.join(random_strings))

# Function to convert file contents to uppercase
def convert_file_to_uppercase(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        uppercase_lines = [line.upper() for line in lines]
    with open(file_path, 'w') as file:
        file.writelines(uppercase_lines)

# File sizes in bytes
file_sizes = [1 * 1024**2, 2 * 1024**2, 3 * 1024**2, 4 * 1024**2, 5 * 1024**2]

# Generate and convert files
for i, size in enumerate(file_sizes):
    # Generate random strings
    num_lines = size // 50  # Approximate number of lines based on average line size
    random_strings = generate_random_strings(num_lines)

    # Create file
    file_path = f'file_{i}.txt'
    write_random_strings_to_file(file_path, random_strings)

    # Convert file to uppercase
    convert_file_to_uppercase(file_path)

# %%
import concurrent.futures

# Function to convert a file to uppercase
def convert_to_uppercase(file_name):
    with open(file_name, 'r') as file:
        lines = file.readlines()

    lines = [line.upper() for line in lines]

    with open(file_name, 'w') as file:
        file.writelines(lines)

    print(f"{file_name} converted to uppercase.")

# List of file names
file_names = ["1GB_file.txt", "2GB_file.txt", "3GB_file.txt", "4GB_file.txt", "5GB_file.txt"]

# Number of threads (adjust as needed)
num_threads = 5

# Create a thread pool executor
with concurrent.futures.ThreadPoolExecutor(max_workers=num_threads) as executor:
    # Submit the tasks to the executor
    results = [executor.submit(convert_to_uppercase, file_name) for file_name in file_names]

    # Wait for all tasks to complete
    concurrent.futures.wait(results)

# %%
# !pip install simple_image_download
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting simple_image_download
#   Downloading simple_image_download-0.5-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from simple_image_download) (2.27.1)
# INFO: pip is looking at multiple versions of simple-image-download to determine which version is compatible with other requirements. This could take a while.
#   Downloading simple_image_download-0.4-py3-none-any.whl (4.9 kB)
#   Downloading simple_image_download-0.2-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->simple_image_download) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->simple_image_download) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->simple_image_download) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->simple_image_download) (3.4)
# Installing collected packages: simple_image_download
# Successfully installed simple_image_download-0.2

# %%
from simple_image_download import simple_image_download as simp
response = simp.simple_image_download
lst = ['Cat']
for rep in lst:
  response().download(rep, 10)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set seed for reproducibility
np.random.seed(42)

# Generate a random dataset
num_rows = 100
num_columns = 30
dataset = pd.DataFrame(np.random.uniform(low=1, high=200, size=(num_rows, num_columns)))

#  Replace values with NA in the defined range [10, 60]
dataset.loc[10:60, :] = np.nan

# Print the count of rows with missing values
missing_rows_count = dataset.isna().sum(axis=1).sum()
print("Number of rows with missing values:", missing_rows_count)

#  Replace NA values with column mean
dataset = dataset.fillna(dataset.mean())

#  Calculate Pearson correlation and plot heat map
cor_matrix = dataset.corr()
sns.heatmap(cor_matrix, annot=True, cmap="coolwarm")
plt.show()

# Select columns with correlation <= 0.7
cor_threshold = 0.7
columns_to_select = cor_matrix.columns[cor_matrix.abs().le(cor_threshold).all()]

#  Normalize values between 0 and 10
dataset_normalized = (dataset - dataset.min()) / (dataset.max() - dataset.min()) * 10

#  Replace values with 1 if <= 0.5, else with 0
dataset_binary = dataset_normalized.applymap(lambda x: 1 if x <= 0.5 else 0)
# Out:
# Number of rows with missing values: 1530

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set seed for reproducibility
np.random.seed(42)

# Generate a random dataset
num_rows = 600
num_columns = 15
column_ranges = (-100, 100)
dataset = np.random.uniform(low=column_ranges[0], high=column_ranges[1], size=(num_rows, num_columns))

#  Plot scatter graph between Column 5 and Column 6
plt.scatter(dataset[:, 4], dataset[:, 5])
plt.xlabel('Column 5')
plt.ylabel('Column 6')
plt.title('Scatter Plot')
plt.show()

#  Plot histogram of each column in single graph
plt.figure(figsize=(10, 6))
for i in range(num_columns):
    plt.hist(dataset[:, i], bins=20, alpha=0.5, label=f'Column {i+1}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Columns')
plt.legend()
plt.show()

#  Plot the Box plot of each column in single graph
plt.figure(figsize=(10, 6))
plt.boxplot(dataset)
plt.xlabel('Column')
plt.ylabel('Value')
plt.title('Box Plot of Columns')
plt.show()
